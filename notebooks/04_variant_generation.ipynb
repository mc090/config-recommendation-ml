# %% [markdown]
# # Variant Generation

# %%
from pathlib import Path

import pandas as pd

from src.experiments.build_variants import build_variants

# %%
dataset_output_dir = Path("data/processed/nb_test")

build_variants(dataset_output_dir)
# Out:
# INFO    | Generating variants from data/processed/nb_test/v1.0.5/dataset.csv
# INFO    | Rows: 25 | Features: 32 | Labels: 10
# INFO    | Saved 1 records -> data/processed/nb_test/v1.0.5/variants/original/variant_manifest.json
# INFO    | Saved variant 'original' with 0 dropped features: data/processed/nb_test/v1.0.5/variants/original/dataset.csv
# INFO    | Skipping pair stars/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair forks/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair repo_size_kb/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair open_issues_count/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_files/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_py_files/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_js_files/recent_activity_days: not enough unique values(feature_a unique: 9, feature_b unique: 1)
# INFO    | Skipping pair num_ts_files/recent_activity_days: not enough unique values(feature_a unique: 4, feature_b unique: 1)
# INFO    | Skipping pair num_html_files/recent_activity_days: not enough unique values(feature_a unique: 7, feature_b unique: 1)
# INFO    | Skipping pair num_css_files/recent_activity_days: not enough unique values(feature_a unique: 8, feature_b unique: 1)
# INFO    | Skipping pair num_json_files/recent_activity_days: not enough unique values(feature_a unique: 14, feature_b unique: 1)
# INFO    | Skipping pair num_sh_files/recent_activity_days: not enough unique values(feature_a unique: 10, feature_b unique: 1)
# INFO    | Skipping pair num_yaml_files/recent_activity_days: not enough unique values(feature_a unique: 18, feature_b unique: 1)
# INFO    | Skipping pair num_test_files/recent_activity_days: not enough unique values(feature_a unique: 18, feature_b unique: 1)
# INFO    | Skipping pair test_file_ratio/recent_activity_days: not enough unique values(feature_a unique: 19, feature_b unique: 1)
# INFO    | Skipping pair num_docs_files/recent_activity_days: not enough unique values(feature_a unique: 22, feature_b unique: 1)
# INFO    | Skipping pair num_notebooks/recent_activity_days: not enough unique values(feature_a unique: 4, feature_b unique: 1)
# INFO    | Skipping pair other_extensions_count/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair has_dedicated_test_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_license/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_src_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_docs_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_scripts_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair num_dirs/recent_activity_days: not enough unique values(feature_a unique: 22, feature_b unique: 1)
# INFO    | Skipping pair avg_files_per_dir/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair avg_py_file_len/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair avg_test_file_len/recent_activity_days: not enough unique values(feature_a unique: 20, feature_b unique: 1)
# INFO    | Skipping pair avg_nb_cell_count/recent_activity_days: not enough unique values(feature_a unique: 3, feature_b unique: 1)
# INFO    | Skipping pair avg_docs_file_len/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_dependencies/recent_activity_days: not enough unique values(feature_a unique: 19, feature_b unique: 1)
# INFO    | Skipping pair repo_age_days/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Saved 1 records -> data/processed/nb_test/v1.0.5/variants/corr_070/variant_manifest.json
# INFO    | Saved variant 'corr_070' with 13 dropped features: data/processed/nb_test/v1.0.5/variants/corr_070/dataset.csv
# INFO    | Skipping pair stars/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair forks/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair repo_size_kb/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair open_issues_count/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_files/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_py_files/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_js_files/recent_activity_days: not enough unique values(feature_a unique: 9, feature_b unique: 1)
# INFO    | Skipping pair num_ts_files/recent_activity_days: not enough unique values(feature_a unique: 4, feature_b unique: 1)
# INFO    | Skipping pair num_html_files/recent_activity_days: not enough unique values(feature_a unique: 7, feature_b unique: 1)
# INFO    | Skipping pair num_css_files/recent_activity_days: not enough unique values(feature_a unique: 8, feature_b unique: 1)
# INFO    | Skipping pair num_json_files/recent_activity_days: not enough unique values(feature_a unique: 14, feature_b unique: 1)
# INFO    | Skipping pair num_sh_files/recent_activity_days: not enough unique values(feature_a unique: 10, feature_b unique: 1)
# INFO    | Skipping pair num_yaml_files/recent_activity_days: not enough unique values(feature_a unique: 18, feature_b unique: 1)
# INFO    | Skipping pair num_test_files/recent_activity_days: not enough unique values(feature_a unique: 18, feature_b unique: 1)
# INFO    | Skipping pair test_file_ratio/recent_activity_days: not enough unique values(feature_a unique: 19, feature_b unique: 1)
# INFO    | Skipping pair num_docs_files/recent_activity_days: not enough unique values(feature_a unique: 22, feature_b unique: 1)
# INFO    | Skipping pair num_notebooks/recent_activity_days: not enough unique values(feature_a unique: 4, feature_b unique: 1)
# INFO    | Skipping pair other_extensions_count/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair has_dedicated_test_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_license/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_src_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_docs_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair has_scripts_dir/recent_activity_days: not enough unique values(feature_a unique: 2, feature_b unique: 1)
# INFO    | Skipping pair num_dirs/recent_activity_days: not enough unique values(feature_a unique: 22, feature_b unique: 1)
# INFO    | Skipping pair avg_files_per_dir/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair avg_py_file_len/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair avg_test_file_len/recent_activity_days: not enough unique values(feature_a unique: 20, feature_b unique: 1)
# INFO    | Skipping pair avg_nb_cell_count/recent_activity_days: not enough unique values(feature_a unique: 3, feature_b unique: 1)
# INFO    | Skipping pair avg_docs_file_len/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Skipping pair num_dependencies/recent_activity_days: not enough unique values(feature_a unique: 19, feature_b unique: 1)
# INFO    | Skipping pair repo_age_days/recent_activity_days: not enough unique values(feature_a unique: 25, feature_b unique: 1)
# INFO    | Saved 1 records -> data/processed/nb_test/v1.0.5/variants/corr_060/variant_manifest.json
# INFO    | Saved variant 'corr_060' with 13 dropped features: data/processed/nb_test/v1.0.5/variants/corr_060/dataset.csv
# INFO    | Saved 1 records -> data/processed/nb_test/v1.0.5/variants/manual_selection/variant_manifest.json
# INFO    | Saved variant 'manual_selection' with 3 dropped features: data/processed/nb_test/v1.0.5/variants/manual_selection/dataset.csv
# INFO    | Saved 1 records -> data/processed/nb_test/v1.0.5/variants/dom_080/variant_manifest.json
# INFO    | Saved variant 'dom_080' with 6 dropped features: data/processed/nb_test/v1.0.5/variants/dom_080/dataset.csv
# INFO    | Saved 1 records -> data/processed/nb_test/v1.0.5/variants/variants_manifest.json
# INFO    | ============================================================
# INFO    | Variant generation complete
# INFO    | Output directory: data/processed/nb_test/v1.0.5/variants
# INFO    | Overview file: data/processed/nb_test/v1.0.5/variants/variant_overview.csv
# INFO    | ============================================================

# %%
version_dirs = sorted(path for path in dataset_output_dir.glob("v*") if path.is_dir())
latest_version = version_dirs[-1]
variants_dir = latest_version / "variants"

print(f"Latest dataset version: {latest_version.name}")
print(f"Variants directory: {variants_dir}")
for dataset_path in sorted(variants_dir.glob("*/dataset.csv")):
    print(" -", dataset_path.relative_to(dataset_output_dir))
# Out:
# Latest dataset version: v1.0.5
# Variants directory: data/processed/nb_test/v1.0.5/variants
#  - v1.0.5/variants/corr_060/dataset.csv
#  - v1.0.5/variants/corr_070/dataset.csv
#  - v1.0.5/variants/dom_080/dataset.csv
#  - v1.0.5/variants/manual_selection/dataset.csv
#  - v1.0.5/variants/original/dataset.csv

# %%
overview = pd.read_csv(variants_dir / "variant_overview.csv")
overview
# Out:
#             variant  rows  total_columns  feature_count  \
# 0          corr_060    25             30             19
# 1          corr_070    25             30             19
# 2           dom_080    25             37             26
# 3  manual_selection    25             40             29
# 4          original    25             43             32
#
#    dropped_feature_count                                   dropped_features  \
# 0                     13  ['forks', 'num_css_files', 'num_dirs', 'num_do...
# 1                     13  ['forks', 'num_css_files', 'num_dirs', 'num_do...
# 2                      6  ['avg_nb_cell_count', 'has_license', 'has_src_...
# 3                      3  ['avg_files_per_dir', 'avg_nb_cell_count', 'ha...
# 4                      0                                                 []
#
#                                         dataset_path  \
# 0  data/processed/nb_test/v1.0.5/variants/corr_06...
# 1  data/processed/nb_test/v1.0.5/variants/corr_07...
# 2  data/processed/nb_test/v1.0.5/variants/dom_080...
# 3  data/processed/nb_test/v1.0.5/variants/manual_...
# 4  data/processed/nb_test/v1.0.5/variants/origina...
#
#                                        manifest_path
# 0  data/processed/nb_test/v1.0.5/variants/corr_06...
# 1  data/processed/nb_test/v1.0.5/variants/corr_07...
# 2  data/processed/nb_test/v1.0.5/variants/dom_080...
# 3  data/processed/nb_test/v1.0.5/variants/manual_...
# 4  data/processed/nb_test/v1.0.5/variants/origina...
