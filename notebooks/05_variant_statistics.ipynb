# %% [markdown]
# # Variant Statistics

# %% [markdown]
# ## 1. Setup and data loading

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# %%
repo_root = Path("..").resolve()
versions_root = repo_root / "data" / "processed"
version_dirs = sorted(path for path in versions_root.glob("v*") if path.is_dir())
latest_version = version_dirs[-1]
variants_dir = latest_version / "variants"

overview_path = variants_dir / "variant_overview.csv"
overview = pd.read_csv(overview_path).sort_values("variant").reset_index(drop=True)

print(f"Dataset version: {latest_version.name}")
print(f"Variants dir: {variants_dir}")
print(f"Variants listed: {len(overview)}")
overview
# Out:
# Dataset version: v1.0.1
# Variants dir: /workspaces/config-recommendation-ml/data/processed/v1.0.1/variants
# Variants listed: 5
#             variant  rows  total_columns  feature_count  \
# 0          corr_060  1465             38             27
# 1          corr_070  1465             40             29
# 2           dom_080  1465             39             28
# 3  manual_selection  1465             40             29
# 4          original  1465             43             32
#
#    dropped_feature_count                                   dropped_features  \
# 0                      5  ['forks', 'num_dirs', 'num_py_files', 'num_tes...
# 1                      3    ['forks', 'num_dirs', 'other_extensions_count']
# 2                      4  ['has_license', 'has_src_dir', 'num_ts_files',...
# 3                      3  ['avg_files_per_dir', 'avg_nb_cell_count', 'ha...
# 4                      0                                                 []
#
#                                         dataset_path  \
# 0  data/processed/v1.0.1/variants/corr_060/datase...
# 1  data/processed/v1.0.1/variants/corr_070/datase...
# 2  data/processed/v1.0.1/variants/dom_080/dataset...
# 3  data/processed/v1.0.1/variants/manual_selectio...
# 4  data/processed/v1.0.1/variants/original/datase...
#
#                                        manifest_path
# 0  data/processed/v1.0.1/variants/corr_060/varian...
# 1  data/processed/v1.0.1/variants/corr_070/varian...
# 2  data/processed/v1.0.1/variants/dom_080/variant...
# 3  data/processed/v1.0.1/variants/manual_selectio...
# 4  data/processed/v1.0.1/variants/original/varian...

# %% [markdown]
# ## 2. Summary statistics

# %%
stats = overview[
    ["variant", "feature_count", "dropped_feature_count", "dropped_features"]
].copy()

stats["retention_ratio"] = (
    stats["feature_count"] / stats["feature_count"].max()
).round(3)

stats["drop_ratio"] = (
    stats["dropped_feature_count"] / stats["feature_count"].max()
).round(3)

display(stats.style.format({"retention_ratio": "{:.1%}", "drop_ratio": "{:.1%}"}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_8e79d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e79d_level0_col0" class="col_heading level0 col0" >variant</th>
#       <th id="T_8e79d_level0_col1" class="col_heading level0 col1" >feature_count</th>
#       <th id="T_8e79d_level0_col2" class="col_heading level0 col2" >dropped_feature_count</th>
#       <th id="T_8e79d_level0_col3" class="col_heading level0 col3" >dropped_features</th>
#       <th id="T_8e79d_level0_col4" class="col_heading level0 col4" >retention_ratio</th>
#       <th id="T_8e79d_level0_col5" class="col_heading level0 col5" >drop_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e79d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e79d_row0_col0" class="data row0 col0" >corr_060</td>
#       <td id="T_8e79d_row0_col1" class="data row0 col1" >27</td>
#       <td id="T_8e79d_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_8e79d_row0_col3" class="data row0 col3" >['forks', 'num_dirs', 'num_py_files', 'num_test_files', 'other_extensions_count']</td>
#       <td id="T_8e79d_row0_col4" class="data row0 col4" >84.4%</td>
#       <td id="T_8e79d_row0_col5" class="data row0 col5" >15.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8e79d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e79d_row1_col0" class="data row1 col0" >corr_070</td>
#       <td id="T_8e79d_row1_col1" class="data row1 col1" >29</td>
#       <td id="T_8e79d_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_8e79d_row1_col3" class="data row1 col3" >['forks', 'num_dirs', 'other_extensions_count']</td>
#       <td id="T_8e79d_row1_col4" class="data row1 col4" >90.6%</td>
#       <td id="T_8e79d_row1_col5" class="data row1 col5" >9.4%</td>
#     </tr>
#     <tr>
#       <th id="T_8e79d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e79d_row2_col0" class="data row2 col0" >dom_080</td>
#       <td id="T_8e79d_row2_col1" class="data row2 col1" >28</td>
#       <td id="T_8e79d_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_8e79d_row2_col3" class="data row2 col3" >['has_license', 'has_src_dir', 'num_ts_files', 'recent_activity_days']</td>
#       <td id="T_8e79d_row2_col4" class="data row2 col4" >87.5%</td>
#       <td id="T_8e79d_row2_col5" class="data row2 col5" >12.5%</td>
#     </tr>
#     <tr>
#       <th id="T_8e79d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e79d_row3_col0" class="data row3 col0" >manual_selection</td>
#       <td id="T_8e79d_row3_col1" class="data row3 col1" >29</td>
#       <td id="T_8e79d_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_8e79d_row3_col3" class="data row3 col3" >['avg_files_per_dir', 'avg_nb_cell_count', 'has_license']</td>
#       <td id="T_8e79d_row3_col4" class="data row3 col4" >90.6%</td>
#       <td id="T_8e79d_row3_col5" class="data row3 col5" >9.4%</td>
#     </tr>
#     <tr>
#       <th id="T_8e79d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e79d_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_8e79d_row4_col1" class="data row4 col1" >32</td>
#       <td id="T_8e79d_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_8e79d_row4_col3" class="data row4 col3" >[]</td>
#       <td id="T_8e79d_row4_col4" class="data row4 col4" >100.0%</td>
#       <td id="T_8e79d_row4_col5" class="data row4 col5" >0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = stats.plot(
    x="variant",
    y=["feature_count", "dropped_feature_count"],
    kind="bar",
    figsize=(10, 4),
    title="Feature counts by variant",
)
ax.set_ylabel("Count")
plt.xticks(rotation=0)
plt.tight_layout()
